# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
Baltimore = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-manipulationStudio\dataset\baltimore_9-24-2016_9-30-2017.csv")
Boston = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-manipulationStudio\dataset\boston_9-24-2016_9-30-2017.csv")
NY = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-manipulationStudio\dataset\new-york_9-24-2016_9-30-2017.csv")
Philly = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-manipulationStudio\dataset\philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
# Clean your data here!

#Boston.head()
#NY.head()
#Philly.head()


    
Baltimore.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
for col in Baltimore.columns:
    pct_missing = np.mean(Baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
Baltimore = Baltimore.drop(["Type","Grade","Origin District","Environment","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)

# %%
Baltimore.columns
# Out:
# Index(['Commodity Name', 'City Name', 'Package', 'Variety', 'Sub Variety',
#        'Date', 'Low Price', 'High Price', 'Mostly Low', 'Mostly High',
#        'Origin', 'Item Size', 'Color', 'Unit of Sale', 'Repack'],
#       dtype='object')

# %%
for col in Boston.columns:
    pct_missing = np.mean(Boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
Boston= Boston.drop(["Type","Grade","Origin District","Environment","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)

# %%
for col in NY.columns:
    pct_missing = np.mean(NY[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
NY = NY.drop(["Type","Grade","Environment","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1) 

    
for col in Philly.columns:
    pct_missing = np.mean(Philly[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
Philly = Philly.drop(["Type","Grade","Origin District","Environment","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# data.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32408\4270916516.py in <module>
# ----> 1 data.duplicated().sum()
#
# NameError: name 'data' is not defined

# %%
# data.drop_duplicates()

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
data=pd.concat([Baltimore,Boston,NY,Philly])
data.shape
# Out:
# (674, 16)

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
# Combine the four dataframes into one!
df=data.groupby(["Package","City Name"]).agg("mean")
df
# Out:
#                                     Low Price  High Price  Mostly Low  \
# Package              City Name
# 1 1/9 bushel cartons BALTIMORE      16.521739   16.847826   16.521739
#                      BOSTON         15.000000   16.000000   15.000000
#                      NEW YORK       16.000000   18.000000   16.000000
#                      PHILADELPHIA   15.000000   16.333333   15.000000
# 1 1/9 bushel crates  BOSTON         15.000000   16.000000   15.000000
#                      NEW YORK       18.000000   18.000000   18.000000
# 1/2 bushel cartons   BALTIMORE      16.066667   16.666667   16.066667
#                      BOSTON         15.000000   17.600000   15.000000
#                      NEW YORK       17.700000   19.000000   18.000000
#                      PHILADELPHIA   16.166667   17.583333   16.166667
# 24 inch bins         BALTIMORE     164.285714  176.571429  164.285714
#                      BOSTON        229.324324  249.324324  247.027027
#                      NEW YORK      144.772727  154.545455  145.227273
#                      PHILADELPHIA  150.833333  157.500000  150.833333
# 36 inch bins         BALTIMORE     140.000000  152.857143  140.000000
#                      BOSTON        180.917431  212.958716  190.825688
#                      NEW YORK      159.700000  175.200000  159.800000
#                      PHILADELPHIA  129.629630  137.592593  130.370370
# 50 lb sacks          BALTIMORE      25.111111   25.333333   25.111111
# bushel cartons       BOSTON         20.000000   24.000000   24.000000
#                      NEW YORK       20.800000   22.400000   20.800000
# each                 NEW YORK       75.000000   80.000000   75.000000
#
#                                    Mostly High
# Package              City Name
# 1 1/9 bushel cartons BALTIMORE       16.847826
#                      BOSTON          15.000000
#                      NEW YORK        18.000000
#                      PHILADELPHIA    16.333333
# 1 1/9 bushel crates  BOSTON          15.000000
#                      NEW YORK        18.000000
# 1/2 bushel cartons   BALTIMORE       16.666667
#                      BOSTON          15.000000
#                      NEW YORK        18.900000
#                      PHILADELPHIA    17.583333
# 24 inch bins         BALTIMORE      176.428571
#                      BOSTON         247.500000
#                      NEW YORK       154.545455
#                      PHILADELPHIA   157.500000
# 36 inch bins         BALTIMORE      151.904762
#                      BOSTON         196.169725
#                      NEW YORK       175.200000
#                      PHILADELPHIA   137.592593
# 50 lb sacks          BALTIMORE       25.333333
# bushel cartons       BOSTON          24.000000
#                      NEW YORK        21.200000
# each                 NEW YORK        80.000000

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
data.groupby(["Variety"])["Package"].count()
# Out:
# Variety
# BIG MACK TYPE                55
# BLUE TYPE                     7
# CINDERELLA                   39
# FAIRYTALE                    37
# HOWDEN TYPE                 224
# HOWDEN WHITE TYPE             2
# KNUCKLE HEAD                  9
# MINIATURE                    97
# MIXED HEIRLOOM VARIETIES      4
# PIE TYPE                    198
# Name: Package, dtype: int64

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
